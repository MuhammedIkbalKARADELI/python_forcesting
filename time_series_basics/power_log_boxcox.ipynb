# %%
from scipy.stats import boxcox
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Applications/Work Space/Python Work Space/python_forcesting/airline_passengers.csv", index_col="Month", parse_dates=True)
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
data["SprtPassengers"] = np.sqrt(data["Passengers"])
data["LogPassengers"] = np.log(data["Passengers"])

# %%
data["Passengers"].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Month'>

# %%
data["SprtPassengers"].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Month'>

# %%
data["LogPassengers"].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Month'>

# %%
data_boxcox, lam = boxcox(data["Passengers"])

# %%
data["BoxcoxPassengers"] = data_boxcox

# %%
lam
# Out:
# 0.14802254856840585

# %%
data["BoxcoxPassengers"].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Month'>

# %%
data["Passengers"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["SprtPassengers"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["LogPassengers"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["BoxcoxPassengers"].hist(bins=20)
# Out:
# <Axes: >
